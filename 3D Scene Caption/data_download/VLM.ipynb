# %%
import math
import numpy as np
import torch
import torchvision.transforms as T
from decord import VideoReader, cpu
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
import internVL
import images_processing

# %%
vlm = internVL.InternVL_VLM()

# %%
top5_images = images_processing.top5_view_selection(object_id=35)
pixel_values, num_patches_list = vlm.image_preprocess(top5_images)
print(vlm.generate_caption(pixel_values=pixel_values,generation_type='object-level', num_patches_list=num_patches_list))
# Out:
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# The object is a decorative lampshade with a conical shape, featuring a vibrant red background adorned with a detailed floral pattern in a lighter shade, creating a visually appealing contrast. The texture appears to be slightly translucent, allowing light to filter through the intricate design, enhancing its aesthetic appeal.

# %%
top5_images = images_processing.top5_view_selection(image_path = 'ScanNet_Data/data/0a7cc12c0e/object_crops_padding_triple', object_id=35)
pixel_values, num_patches_list = vlm.image_preprocess(top5_images)
categoryy = vlm.generate_caption(pixel_values=pixel_values,generation_type='object-category', num_patches_list=num_patches_list)
object_caption = vlm.generate_caption(pixel_values=pixel_values,generation_type='object-level', num_patches_list=num_patches_list)
object_surroudning = vlm.generate_caption(pixel_values=pixel_values,generation_type='object-surrounding', num_patches_list=num_patches_list)

print(f'Category: {categoryy}')
print(f'Object Caption: {object_caption}')
print(f'Object Surrounding: {object_surroudning}')
# Out:
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Category: Lamp
# Object Caption: A red lamp with a floral pattern, placed on a white surface against a beige wall.
# Object Surrounding: This object is a red lamp with a floral pattern.
# It is placed on a white surface, likely a bedside table.
# It is positioned next to a bed with a patterned bedspread.
# It is connected to an electrical outlet by a cord.
